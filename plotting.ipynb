# %%
# import the libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# get the data set
fifa_data = pd.read_csv('fifa.csv', index_col="Date", parse_dates=True)

# %%
# inspect the data for first hand
fifa_data.head()

# %% [markdown]
# ## plot

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Fill in the line below: Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data)

# %%
r = [0, 4]
df = fifa_data.iloc[:,r]
df.head()

# %%
plt.figure(figsize=(16,6))

# Fill in the line below: Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=df)

# %%
plt.figure(figsize=(16,6))

# Fill in the line below: Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data.ARG)

# %%
plt.figure(figsize=(16,6))
sns.lineplot(y=fifa_data.ARG, x=fifa_data.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fd1f4a935fb3> in <module>
#       1 plt.figure(figsize=(16,6))
# ----> 2 sns.lineplot(y=fifa_data.ARG, x=fifa_data.index)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## Bar charts

# %%
tf = df.iloc[0:5]

plt.figure(figsize=(16,6))
plt.title('bar chart')
sns.barplot(x=tf.index, y=tf.GER)
plt.ylabel('GER label')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %% [markdown]
# ## heatmaps

# %%
plt.figure(figsize=(10,5))
plt.title('heatmap')

sns.heatmap(data=fifa_data.iloc[:6,:], annot=True)

# %% [markdown]
# ## Scatter plot

# %%
td = pd.read_csv('insurance.csv')#, index_col='id')
td.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=td.bmi, y=td.charges, marker='^')
#sns.heatmap(data=td, annot=True)

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=td.bmi, y=td.charges, hue=td.smoker)
#sns.heatmap(data=td, annot=True)

# %% [markdown]
# ### fitting a regression line to above graph to understande the correlance

# %%
th = td[td.smoker=='yes']

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=th.bmi, y=th.charges)

# %% [markdown]
# ## Histogram

# %%
sns.distplot(a=th.bmi, kde=False)

# %% [markdown]
# ## Density plot

# %%
sns.kdeplot(data=th.bmi, shade=False)

# %% [markdown]
# ## 2d KDE plot

# %%
sns.jointplot(x=th.bmi, y=th.charges, kind="kde")

# %%
th = pd.read_csv('candy.csv')
th.head()
# Out:
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %%
th = pd.read_csv('candy.csv')
fig, arr = plt.subplots(2,1, figsize=(10,5))
#arr[0] = sns.kdeplot(data=th.bmi, shade=False)
#arr[1] = sns.distplot(a=th.bmi, kde=False)
th.sugarpercent.plot.bar(ax=arr[0])
th.pricepercent.plot.bar(ax=arr[1])

# %%
years = data.columns
gdp_australia = data.loc['Australia']

plt.plot(years, gdp_australia, 'g--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6552f26b754c> in <module>
# ----> 1 years = data.columns
#       2 gdp_australia = data.loc['Australia']
#       3
#       4 plt.plot(years, gdp_australia, 'g--')
#
# NameError: name 'data' is not defined

# %%
import matplotlib.pyplot as bar

# %%
time = [0, 1, 2, 3]
position = [0, 100, 500, 800]
plt.bar(time, position)
plt.xlabel('Time for city (hr)')
plt.ylabel('Position (km)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a61847d79978> in <module>
#       1 time = [0, 1, 2, 3]
#       2 position = [0, 100, 500, 800]
# ----> 3 plt.bar(time, position)
#       4 plt.xlabel('Time for city (hr)')
#       5 plt.ylabel('Position (km)')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 100, 500, 800]

plt.bar(time, position)
plt.xlabel('Time for city (hr)')
plt.ylabel('Position (km)')

# %%
time = [0, 1, 2, 3]
position = [0, 100, 500, 800]

plt.plot(time, position)
plt.xlabel('Time for city (hr--)')
plt.ylabel('Position km--')

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,] 
# corresponding y axis values 
y = [2,4,1] 

# plotting the points 
plt.plot(x, y) 

# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 

# giving a title to my graph 
plt.title('My first graph!') 

# function to show the plot 
plt.show()

# %% [raw]
# x = [1,2,3,4,5,6]
# # corresponding y axis values
# y = [2,4,1,5,2,6]
#
# # plotting the points
# plt.plot(x, y, color='blue', linestyle='dashed', linewidth = 5,
# 		marker='o', markerfacecolor='white', markersize=10)
#
# # setting x and y axis range
# plt.ylim(1,8)
# plt.xlim(1,8)
#
# # naming the x axis
# plt.xlabel('x - axis')
# # naming the y axis
# plt.ylabel('y - axis')
#
# # giving a title to my graph
# plt.title('Some cool customizations!')
#
# # function to show the plot
# plt.show()

# %%
activities = ['eat', 'sleep', 'work', 'play'] 


slices = [3, 7, 8, 6] 

 
colors = ['r', 'y', 'g', 'b'] 

plt.pie(slices, labels = activities, colors=colors, 
		startangle=90, shadow = True, explode = (0, 0, 0.1, 0), 
		radrnius = 1.2, autopct = '%1.1f%%') 

 
plt.legend() 


plt.show()

# %%
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 100, 500, 800]

plt.plot(time, position)
plt.xlabel('Time for city (hr--)')
plt.ylabel('Position km--')
# Out:
# Text(0,0.5,'Position km--')

# %%
time = [0, 1, 2, 3]
position = [0, 100, 500, 800]

plt.scatter(time, position)
plt.xlabel('Time for city (hr--)')
plt.ylabel('Position km--')
# Out:
# Text(0,0.5,'Position km--')
